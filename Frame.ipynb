# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys
from PIL import Image

# %%
images = map(Image.open, ['/home/pranav/Desktop/static_qr_code_without_logo.jpg','/home/pranav/Desktop/Lost Dog?.png'])
widths, heights = zip(*(i.size for i in images))

total_width = sum(widths)
max_height = max(heights)

new_im = Image.new('RGB', (total_width, max_height))

x_offset = 0
for im in images:
    new_im.paste(im, (x_offset, 0))
    x_offset +=im.size[0]
plt.imshow(new_im)
