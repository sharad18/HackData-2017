# %%
import pandas as pd
import numpy as np
import os, sys
from collections import defaultdict
import cv2

# %%
lis=os.listdir('dog/')

# %%
l1=[]
for i in lis:
    l1.append((i))
d1=[0]*len(l1)

# %%
lis=os.listdir('./StrayDog/')

# %%
for i in lis:
    l1.append((i))
d1.extend([1]*(len(lis)))

# %%
len(d1)
# Out:
# 14720

# %%
lis=os.listdir('piga/')

# %%
for i in lis:
    l1.append((i))
d1.extend([2]*(len(lis)))

# %%
len(d1)
# Out:
# 16610

# %%
lis=os.listdir('monkeyAugmentation/')

# %%
for i in lis:
    l1.append((i))
d1.extend([3]*(len(lis)))

# %%
len(d1)
# Out:
# 18460

# %%
lis=os.listdir('cataugmentation/')

# %%
for i in lis:
    l1.append((i))
d1.extend([4]*(len(lis)))

# %%
lis=os.listdir('CowAugmentation/')

# %%
for i in lis:
    l1.append((i))
d1.extend([5]*(len(lis)))

# %%
np.unique(d1, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([11500,  3220,  1890,  1850,  1830,  1790]))

# %%
l1
# Out:
# ['dogs-1007049.jpg',
#  'dogs-1004214.jpg',
#  'dogs-1002882.jpg',
#  'dogs-10010989.jpg',
#  'dogs-10010530.jpg',
#  'dogs-1008691.jpg',
#  'dogs-100634.jpg',
#  'dogs-1008339.jpg',
#  'dogs-100835.jpg',
#  'dogs-1005898.jpg',
#  'dogs-1001085.jpg',
#  'dogs-1007465.jpg',
#  'dogs-1005475.jpg',
#  'dogs-1004066.jpg',
#  'dogs-1002238.jpg',
#  'dogs-1006460.jpg',
#  'dogs-1001714.jpg',
#  'dogs-1009346.jpg',
#  'dogs-100924.jpg',
#  'dogs-1004105.jpg',
#  'dogs-1009353.jpg',
#  'dogs-1001183.jpg',
#  'dogs-1004584.jpg',
#  'dogs-10011352.jpg',
#  'dogs-10011052.jpg',
#  'dogs-1005357.jpg',
#  'dogs-1006798.jpg',
#  'dogs-1002453.jpg',
#  'dogs-10010065.jpg',
#  'dogs-1006155.jpg',
#  'dogs-1005585.jpg',
#  'dogs-1003035.jpg',
#  'dogs-1008682.jpg',
#  'dogs-1005830.jpg',
#  'dogs-1004464.jpg',
#  'dogs-1003856.jpg',
#  'dogs-1005652.jpg',
#  'dogs-1008022.jpg',
#  'dogs-100783.jpg',
#  'dogs-1003437.jpg',
#  'dogs-10010955.jpg',
#  'dogs-1002673.jpg',
#  'dogs-1007642.jpg',
# ...

# %%
df = pd.DataFrame({'Image': l1, 'label': d1})

# %%
df.head()
# Out:
#                Image  label
# 0   dogs-1007049.jpg      0
# 1   dogs-1004214.jpg      0
# 2   dogs-1002882.jpg      0
# 3  dogs-10010989.jpg      0
# 4  dogs-10010530.jpg      0

# %%
df.to_csv('DB.csv',header=False)

# %%
df.to_

# %%
l=[]
for i in lis:
    l.append((i))
# print(l)
# Out:
# ['4718.jpg', '12016.jpg', '2612.jpg', '381.jpg', '11518.jpg', '150.jpg', '609.jpg', '1409.jpg', '5910.jpg', '10511.jpg', '1142.jpg', '12914.jpg', '8517.jpg', '11615.jpg', '881.jpg', '121.jpg', '1438.jpg', '1453.jpg', '4018.jpg', '6611.jpg', '1616.jpg', '1112.jpg', '9613.jpg', '16515.jpg', '1666.jpg', '29.jpg', '635.jpg', '14014.jpg', '1619.jpg', '14315.jpg', '1534.jpg', '354.jpg', '990.jpg', '120.jpg', '5715.jpg', '15312.jpg', '710.jpg', '245.jpg', '8414.jpg', '371.jpg', '5317.jpg', '9417.jpg', '14815.jpg', '746.jpg', '2715.jpg', '1263.jpg', '1562.jpg', '569.jpg', '1519.jpg', '554.jpg', '11112.jpg', '15411.jpg', '1090.jpg', '1023.jpg', '1293.jpg', '1083.jpg', '167.jpg', '1385.jpg', '2116.jpg', '637.jpg', '13210.jpg', '15914.jpg', '57.jpg', '542.jpg', '11211.jpg', '13719.jpg', '1622.jpg', '08.jpg', '8712.jpg', '1345.jpg', '304.jpg', '876.jpg', '11811.jpg', '11714.jpg', '50.jpg', '939.jpg', '5319.jpg', '69.jpg', '14017.jpg', '714.jpg', '1415.jpg', '203.jpg', '3816.jpg', '1488.jpg', '95
# ...

# %%
df.append({"Image":l, 'label':d})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a846804d9487> in <module>()
# ----> 1 df.append({"Image":l, 'label':d})
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    4613                 other = Series(other)
#    4614             if other.name is None and not ignore_index:
# -> 4615                 raise TypeError('Can only append a Series if ignore_index=True'
#    4616                                 ' or if the Series has a name')
#    4617
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name

# %%
len(l)
# Out:
# 3220

# %%
d=[1]*3220
